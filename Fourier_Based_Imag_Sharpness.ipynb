# %%
import numpy as np
import cv2
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import os
import glob

# %%
imgs = glob.glob("D:/Code/Datasets/Research_Datasets/Focuser/bznick98 Focus_Stacking master assets-test_images/test7/"+"*.jpg")

# %%
def focus(img):
    img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
    print(img.shape)
    f = np.fft.fft2(img)
    fshift = np.fft.fftshift(f)
    print(fshift.shape)
    magnitude_spectrum = 20 * np.log(np.abs(fshift))
    
    x = np.linspace(0, 1, 325)
    y = np.linspace(0, 1, 217)
    X, Y = np.meshgrid(x, y)
    
    highpass = 1 - np.exp(- ((X - 0.5) ** 2 + (Y - 0.5) ** 2) * 5)
    print(np.shape(highpass))
    f2 = fshift * highpass
    z3 = np.absolute(np.fft.ifft2(f2))
    
    plt.subplot(337)
    plt.imshow(z3)
    plt.title('only high frequency content survived')
    plt.colorbar()
    plt.subplot(338)
    plt.imshow(highpass)
    plt.title('highpass, suppresses \n low frequencies')
    plt.colorbar()
    plt.subplot(339)
    plt.imshow(np.log10(np.abs(fshift * highpass)), cmap='gray')
    plt.title('FFT*highpass')
    plt.colorbar()
    plt.show()

# %%
img = cv2.imread(imgs[0], cv2.IMREAD_GRAYSCALE)
print(img.shape)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
print(fshift.shape)
magnitude_spectrum = 20 * np.log(np.abs(fshift))

x = np.linspace(0, 1, 325)
y = np.linspace(0, 1, 217)
X, Y = np.meshgrid(x, y)

highpass = 1 - np.exp(- ((X - 0.5) ** 2 + (Y - 0.5) ** 2) * 5)
print(np.shape(highpass))
f2 = fshift * highpass
z3 = np.absolute(np.fft.ifft2(f2))



plt.subplot(337)
plt.imshow(z3)
plt.title('only high frequency content survived')
plt.colorbar()
plt.subplot(338)
plt.imshow(highpass)
plt.title('highpass, suppresses \n low frequencies')
plt.colorbar()
plt.subplot(339)
plt.imshow(np.log10(np.abs(fshift * highpass)), cmap='gray')
plt.title('FFT*highpass')
plt.colorbar()
plt.show()
# Out:
# (217, 325)
# (217, 325)
# (217, 325)
# C:\Users\aryac\AppData\Local\Temp\ipykernel_22636\2025660352.py:28: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(np.abs(fshift * highpass)), cmap='gray')

# %%
img = cv2.imread(imgs[0], cv2.IMREAD_GRAYSCALE)
print(img.shape)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
print(fshift.shape)
magnitude_spectrum = 20 * np.log(np.abs(fshift))

x = np.linspace(0, 1, 325)
y = np.linspace(0, 1, 217)
X, Y = np.meshgrid(x, y)

highpass = 1 - np.exp(- ((X - 0.5) ** 2 + (Y - 0.5) ** 2) * 5)
print(np.shape(highpass))
f2 = fshift * highpass
z3 = np.absolute(np.fft.ifft2(f2))

fig, ax = plt.subplots(3, figsize=(10,10))
fig.subplots_adjust(wspace = 0.4, hspace = 0.4)

ax[0].imshow(z3)
ax[0].set_title('only high frequency content survived')


ax[1].imshow(highpass)
ax[1].set_title('highpass, suppresses \n low frequencies')
# ax[1].colorbar()

ax[2].imshow(np.log10(np.abs(fshift * highpass)), cmap='gray')
ax[2].set_title('FFT*highpass')
# ax[2].colorbar()
# Out:
# (217, 325)
# (217, 325)
# (217, 325)
# C:\Users\aryac\AppData\Local\Temp\ipykernel_22636\1156264320.py:28: RuntimeWarning: divide by zero encountered in log10
#   ax[2].imshow(np.log10(np.abs(fshift * highpass)), cmap='gray')
# Text(0.5, 1.0, 'FFT*highpass')

# %%
np.sum(z3)
# Out:
# 26460.373035870423

# %%
img = cv2.imread(imgs[23], cv2.IMREAD_GRAYSCALE)
print(img.shape)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
print(fshift.shape)
magnitude_spectrum = 20 * np.log(np.abs(fshift))

x = np.linspace(0, 1, 325)
y = np.linspace(0, 1, 217)
X, Y = np.meshgrid(x, y)

highpass = 1 - np.exp(- ((X - 0.5) ** 2 + (Y - 0.5) ** 2) * 5)
print(np.shape(highpass))
f2 = fshift * highpass
z3 = np.absolute(np.fft.ifft2(f2))

fig, ax = plt.subplots(3, figsize=(10,10))
fig.subplots_adjust(wspace = 0.4, hspace = 0.4)

ax[0].imshow(z3)
ax[0].set_title('only high frequency content survived')


ax[1].imshow(highpass)
ax[1].set_title('highpass, suppresses \n low frequencies')
# ax[1].colorbar()

ax[2].imshow(np.log10(np.abs(fshift * highpass)), cmap='gray')
ax[2].set_title('FFT*highpass')
# ax[2].colorbar()
# Out:
# (217, 325)
# (217, 325)
# (217, 325)
# C:\Users\aryac\AppData\Local\Temp\ipykernel_22636\2924021570.py:28: RuntimeWarning: divide by zero encountered in log10
#   ax[2].imshow(np.log10(np.abs(fshift * highpass)), cmap='gray')
# Text(0.5, 1.0, 'FFT*highpass')

# %%
np.sum(z3)
# Out:
# 133778.00462867314

# %%
vals = []
for i in range(len(imgs)):
    img = cv2.imread(imgs[i], cv2.IMREAD_GRAYSCALE)
    print(img.shape)
    f = np.fft.fft2(img)
    fshift = np.fft.fftshift(f)
    print(fshift.shape)
    magnitude_spectrum = 20 * np.log(np.abs(fshift))
    
    x = np.linspace(0, 1, 325)
    y = np.linspace(0, 1, 217)
    X, Y = np.meshgrid(x, y)
    
    highpass = 1 - np.exp(- ((X - 0.5) ** 2 + (Y - 0.5) ** 2) * 5)
    # print(np.shape(highpass))
    f2 = fshift * highpass
    z3 = np.absolute(np.fft.ifft2(f2))
    vals.append(np.sum(z3))

print(vals)
# Out:
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# (217, 325)
# ...

# %%
plt.plot(vals)

# %%
# Out:
# 217
